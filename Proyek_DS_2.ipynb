# %% [markdown]
# <a href="https://colab.research.google.com/github/DhavaAdePratama/Students_Performance/blob/main/Proyek_DS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Akhir: Menyelesaikan Permasalahan Perusahaan Edutech

# %% [markdown]
# - Nama:Dhava Ade Pratama
# - Email:dhavaadepratama23@gmail.com
# - Id Dicoding:DHAVA ADE PRATAMA

# %% [markdown]
# ## Persiapan

# %% [markdown]
# #####Business Understanding

# %% [markdown]
# Jaya Jaya Institute yang merupakan institusi pendidikan memiliki permasalahan mengenai para siswanya tidak menyelesaikan pendidikannya/DropOut
#
# Tujuan dari proyek ini adalah untuk mengidentifikasi Siswa Siswa mana saja yang berkemungkinan akan melakukan dropout, sehingga mereka dapat di beri bimbingan khusus

# %% [markdown]
# ### Menyiapkan library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Menyiapkan data yang akan digunakan

# %%
df= pd.read_csv("data.csv", sep= ';')
df.head(5)
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %% [markdown]
# ## Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Marital_status                                4424 non-null   int64
#  1   Application_mode                              4424 non-null   int64
#  2   Application_order                             4424 non-null   int64
#  3   Course                                        4424 non-null   int64
#  4   Daytime_evening_attendance                    4424 non-null   int64
#  5   Previous_qualification                        4424 non-null   int64
#  6   Previous_qualification_grade                  4424 non-null   float64
#  7   Nacionality                                   4424 non-null   int64
#  8   Mothers_qualification                         4424 non-null   int64
# ...

# %% [markdown]
# Pada data ini kita memiliki 36 kolom data serta memiliki 4424 baris data, dan jika dilihat dari baris data, data ini tidak memiliki nilai yang miss

# %%
df.isna().sum()
# Out:
# Marital_status                                  0
# Application_mode                                0
# Application_order                               0
# Course                                          0
# Daytime_evening_attendance                      0
# Previous_qualification                          0
# Previous_qualification_grade                    0
# Nacionality                                     0
# Mothers_qualification                           0
# Fathers_qualification                           0
# Mothers_occupation                              0
# Fathers_occupation                              0
# Admission_grade                                 0
# Displaced                                       0
# Educational_special_needs                       0
# Debtor                                          0
# Tuition_fees_up_to_date                         0
# Gender                                          0
# Scholarship_holder                              0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Marital_status  Application_mode  Application_order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime_evening_attendance  Previous_qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# ...

# %% [markdown]
# Berdasarkan analisis deskriptif tidak ada mengindikasikan data yang tidak wajar

# %% [markdown]
# ## Data Preparation / Preprocessing

# %%
df['Status'].value_counts()
# Out:
# Status
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
df['Status'].value_counts()
sns.countplot(data=df, x='Status', palette='Set2')
plt.title('Students Status')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-10-9ec6d221e52d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Status', palette='Set2')

# %% [markdown]
# Jika dilihat data visualisasi, siswa yang berstatus Dropout terbanyak kedua dari total siswa

# %%
df_dropout = df[df['Status'] == 'Dropout']  # Ganti 'Dropout' jika label berbeda

# Hitung jumlah dropout berdasarkan pendidikan ayah
plt.figure(figsize=(10, 6))
sns.countplot(data=df_dropout, x='Fathers_qualification', order=df_dropout['Fathers_qualification'].value_counts().index, palette='Greens')
plt.title('Jumlah Mahasiswa Dropout Berdasarkan Pendidikan Ayah')
plt.xlabel('Tingkat Pendidikan Ayah')
plt.ylabel('Jumlah Dropout')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-05bfcff64c2f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_dropout, x='Fathers_qualification', order=df_dropout['Fathers_qualification'].value_counts().index, palette='Greens')

# %% [markdown]
# hasil dari visualisasi diatas menyatakan bahwa kebanyakan anak Dropout berasal dari pendidikan ayah yang kurang baik. bisa dilihat dari 3 besar yang tertinggi hanya sampai penddidikan dasar siklus 1, kemudian yang ke 2 hanya sampai lulus sma kelas 12, dan ketiga pendidikan dasar siklus 3

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_dropout, x='Mothers_qualification', order=df_dropout['Mothers_qualification'].value_counts().index, palette='Reds')
plt.title('Jumlah Mahasiswa Dropout Berdasarkan Pendidikan Ibu')
plt.xlabel('Tingkat Pendidikan Ibu')
plt.ylabel('Jumlah Dropout')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-d0cbaa1477f4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_dropout, x='Mothers_qualification', order=df_dropout['Mothers_qualification'].value_counts().index, palette='Reds')

# %% [markdown]
# Begitupun dari tingkat pendidikan ibu, hasilnya benar benar mirip dengan total siswa DO berdasarkan pendidikan ayah

# %%
# Hitung jumlah dropout berdasarkan Pekerjaan Ayah
plt.figure(figsize=(10, 6))
sns.countplot(data=df_dropout, x='Fathers_occupation', order=df_dropout['Fathers_occupation'].value_counts().index, palette='Greens')
plt.title('Jumlah Mahasiswa Dropout Berdasarkan Pekerjaan Ayah')
plt.xlabel('Pekerjaan Ayah')
plt.ylabel('Jumlah Dropout')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-04ae21f619a1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_dropout, x='Fathers_occupation', order=df_dropout['Fathers_occupation'].value_counts().index, palette='Greens')

# %% [markdown]
# bisa terlihat dari visualisasi diatas berdasarkan pekerjaan ayah siswa yang dropout kebanyakan ayahnya seorang yang bekerja sebagai pekerja tidak terampil

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_dropout, x='Mothers_occupation', order=df_dropout['Mothers_occupation'].value_counts().index, palette='Reds')
plt.title('Jumlah Mahasiswa Dropout Berdasarkan Pekerjaan Ibu')
plt.xlabel('Pekerjaan Ibu')
plt.ylabel('Jumlah Dropout')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-9819ee74748f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_dropout, x='Mothers_occupation', order=df_dropout['Mothers_occupation'].value_counts().index, palette='Reds')

# %% [markdown]
# begitupun Berdasarkan pekerjaan ibu, Tertinggi nya juga bekerja sebagai pekerja tidak terampil

# %%
grouped = df.groupby(['Status', 'Scholarship_holder']).size().reset_index(name='Jumlah')
print(grouped)
# Out:
#      Status  Scholarship_holder  Jumlah
# 0   Dropout                   0    1287
# 1   Dropout                   1     134
# 2  Enrolled                   0     664
# 3  Enrolled                   1     130
# 4  Graduate                   0    1374
# 5  Graduate                   1     835

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=grouped, x='Status', y='Jumlah', hue='Scholarship_holder')
plt.title('Jumlah Mahasiswa berdasarkan Status dan Beasiswa')
plt.ylabel('Jumlah Mahasiswa')
plt.xlabel('Status')
plt.legend(title='Penerima Beasiswa')
plt.tight_layout()
plt.show()

# %% [markdown]
# berdasarkan hasil visualisasi diatas, kita bisa lihat bahwa kebanyakan siswa yang dropout tidak mendapatkan beasiswa

# %%
grouped_pay= df.groupby(['Status', 'Tuition_fees_up_to_date']).size().reset_index(name='Jumlah')
print(grouped_pay)

sns.barplot(data=grouped_pay, x='Status', y='Jumlah', hue='Tuition_fees_up_to_date')
plt.title('Jumlah Mahasiswa berdasarkan pembayaran nya')
plt.ylabel('Jumlah Mahasiswa')
plt.xlabel('Status')
plt.legend(title='Pembayaran tepat waktu')
plt.tight_layout()
plt.show()
# Out:
#      Status  Tuition_fees_up_to_date  Jumlah
# 0   Dropout                        0     457
# 1   Dropout                        1     964
# 2  Enrolled                        0      42
# 3  Enrolled                        1     752
# 4  Graduate                        0      29
# 5  Graduate                        1    2180

# %% [markdown]
# kita bisa lihat, bahwa kebanyakan yang dropout juga tidak melakukan pembayaran tepat waktu

# %% [markdown]
# #### Data Preprocessing

# %%
cleaned_df = df[['Status', 'Fathers_qualification', 'Mothers_qualification', 'Fathers_occupation', 'Mothers_occupation','Scholarship_holder', 'Tuition_fees_up_to_date']]
cleaned_df.head()
# Out:
#      Status  Fathers_qualification  Mothers_qualification  Fathers_occupation  \
# 0   Dropout                     12                     19                   9
# 1  Graduate                      3                      1                   3
# 2   Dropout                     37                     37                   9
# 3  Graduate                     37                     38                   3
# 4  Graduate                     38                     37                   9
#
#    Mothers_occupation  Scholarship_holder  Tuition_fees_up_to_date
# 0                   5                   0                        1
# 1                   3                   0                        0
# 2                   9                   0                        0
# 3                   5                   0                        1
# 4                   9                   0                        1

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(cleaned_df, test_size=0.20, random_state=42, shuffle=True)
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

print(train_df.shape)
print(test_df.shape)
# Out:
# (3539, 7)
# (885, 7)

# %% [markdown]
# membagi data antara data taraining 80% dan testing 20%

# %%
sns.countplot(data=train_df, x="Status")
plt.show()

# %% [markdown]
# disini kita melihat sample yang tidak balance, sehingga kita harus menyetarakan data di setiap label nya

# %%
train_df.Status.value_counts()
# Out:
# Status
# Graduate    1791
# Dropout     1105
# Enrolled     643
# Name: count, dtype: int64

# %% [markdown]
# kita bisa lihat status enrolled data nya paling sedikit

# %%
df_majority_1 = train_df[(train_df.Status == "Graduate")]
df_majority_2 = train_df[(train_df.Status == "Dropout")]
df_minority = train_df[(train_df.Status == "Enrolled")]

from sklearn.utils import resample

df_majority_1_undersampled = resample(df_majority_1, n_samples=643, random_state=42)
df_majority_2_undersampled = resample(df_majority_2, n_samples=643, random_state=42)
print(df_majority_1_undersampled.shape)
print(df_majority_2_undersampled.shape)
# Out:
# (643, 7)
# (643, 7)

# %% [markdown]
# Disini kita melakukan undersampling, Dimana kita menyetarakan jumlah data pada label nya menjadi yang paling sedikit diantara label

# %%
from sklearn.utils import shuffle

undersampled_train_df = pd.concat([df_minority, df_majority_1_undersampled]).reset_index(drop=True)
undersampled_train_df = pd.concat([undersampled_train_df, df_majority_2_undersampled]).reset_index(drop=True)
undersampled_train_df = shuffle(undersampled_train_df, random_state=42)
undersampled_train_df.reset_index(drop=True, inplace=True)
undersampled_train_df.sample(5)
# Out:
#         Status  Fathers_qualification  Mothers_qualification  \
# 1430  Graduate                     37                     38
# 301   Graduate                      1                      1
# 356    Dropout                     34                     34
# 563   Enrolled                     37                     37
# 1269  Enrolled                     38                     38
#
#       Fathers_occupation  Mothers_occupation  Scholarship_holder  \
# 1430                   4                   4                   1
# 301                    6                   4                   1
# 356                   99                  99                   0
# 563                    6                   9                   0
# 1269                   5                   5                   1
#
#       Tuition_fees_up_to_date
# 1430                        1
# 301                         1
# 356                         1
# 563                         1
# 1269                        1

# %%
sns.countplot(data=undersampled_train_df, x="Status")
plt.show()

# %% [markdown]
# ini hasil data yang telah di undersampling

# %%
X_train = undersampled_train_df.drop(columns="Status", axis=1)
y_train = undersampled_train_df["Status"]

X_test = test_df.drop(columns="Status", axis=1)
y_test = test_df["Status"]

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import joblib
import numpy as np

def scaling(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))

            X_test = np.asanyarray(df_test[feature])
            X_test = X_test.reshape(-1,1)
            df_test["{}".format(feature)] = scaler.transform(X_test)
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))
        return df

def encoding(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))

            df_test["{}".format(feature)] = encoder.transform(df_test[feature])
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))
        return df

# %% [markdown]
# Disini kita memisahkan terlebih dahulu feature training dan targetnya, kemudian kita membuat sebuah fungsi untuk proses encoding dan juga scaling

# %%
df['Status'] = df['Status'].astype(str)

# %%
numerical_columns = [
    'Fathers_qualification',
    'Mothers_qualification',
    'Fathers_occupation',
    'Mothers_occupation',
    'Scholarship_holder',
    'Tuition_fees_up_to_date'

]

categorical_columns = ['Status']

new_train_df, new_test_df = scaling(numerical_columns, X_train, X_test)
new_train_df, new_test_df = encoding(categorical_columns, new_train_df, new_test_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-bb5da4902614> in <cell line: 0>()
#      12
# ...

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import joblib

def scaling(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))

            X_test = np.asanyarray(df_test[feature])
            X_test = X_test.reshape(-1,1)
            df_test["{}".format(feature)] = scaler.transform(X_test)
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))
        return df

def encoding(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))

            df_test["{}".format(feature)] = encoder.transform(df_test[feature])
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))
        return df


numerical_columns = [
    'Fathers_qualification',
    'Mothers_qualification',
    'Fathers_occupation',
    'Mothers_occupation',
    'Scholarship_holder',
    'Tuition_fees_up_to_date'
]

X_train_scaled, X_test_scaled = scaling(numerical_columns, X_train, X_test)

categorical_columns = ['Status']

y_train_encoded, y_test_encoded = encoding(categorical_columns, y_train, y_test)

encoder = LabelEncoder()
encoder.fit(y_train)
y_train_encoded = encoder.transform(y_train)
y_test_encoded = encoder.transform(y_test)
joblib.dump(encoder, "model/encoder_Status.joblib")

new_train_df, new_test_df = scaling(numerical_columns, X_train, X_test)
new_train_df, new_test_df = encoding(categorical_columns, new_train_df, new_test_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-4404fdbdfd72> in <cell line: 0>()
#      66 categorical_columns = ['Status']
#      67
# ---> 68 y_train_encoded, y_test_encoded = encoding(categorical_columns, y_train, y_test)
#      69
#      70 encoder = LabelEncoder()
#
# <ipython-input-46-4404fdbdfd72> in encoding(features, df, df_test)
#      37         for feature in features:
#      38             encoder = LabelEncoder()
# ---> 39             encoder.fit(df[feature])
#      40             df["{}".format(feature)] = encoder.transform(df[feature])
#      41             joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
# ...

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import joblib

# Fungsi Scaling
def scaling(features, df, df_test=None):
    df = df.copy()
    if df_test is not None:
        df_test = df_test.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = df[[feature]]
            scaler.fit(X)
            df[feature] = scaler.transform(X)
            joblib.dump(scaler, f"model/scaler_{feature}.joblib")

            X_test = df_test[[feature]]
            df_test[feature] = scaler.transform(X_test)
        return df, df_test
    else:
        for feature in features:
            scaler = MinMaxScaler()
            X = df[[feature]]
            scaler.fit(X)
            df[feature] = scaler.transform(X)
            joblib.dump(scaler, f"model/scaler_{feature}.joblib")
        return df

# Fungsi Encoding
def encoding(features, df, df_test=None):
    df = df.copy()
    if df_test is not None:
        df_test = df_test.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df[feature] = encoder.transform(df[feature])
            df_test[feature] = encoder.transform(df_test[feature])
            joblib.dump(encoder, f"model/encoder_{feature}.joblib")
        return df, df_test
    else:
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df[feature] = encoder.transform(df[feature])
            joblib.dump(encoder, f"model/encoder_{feature}.joblib")
        return df

# Kolom numerik
numerical_columns = [
    'Fathers_qualification',
    'Mothers_qualification',
    'Fathers_occupation',
    'Mothers_occupation',
    'Scholarship_holder',
    'Tuition_fees_up_to_date'
]

# Kolom target
target_column = 'Status'

# Pisahkan fitur dan target
X_train_scaled, X_test_scaled = scaling(numerical_columns, X_train, X_test)

# Gabungkan kembali jika kamu punya kolom kategorikal di X selain numerik
# Misal: X_train['Something'] yang non-numerik → encoding

# Encode target saja
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train[target_column])
y_test_encoded = label_encoder.transform(y_test[target_column])
joblib.dump(label_encoder, f"model/encoder_{target_column}.joblib")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-e0ce84f556ae> in <cell line: 0>()
#      68 # Encode target saja
#      69 label_encoder = LabelEncoder()
# ---> 70 y_train_encoded = label_encoder.fit_transform(y_train[target_column])
#      71 y_test_encoded = label_encoder.transform(y_test[target_column])
#      72 joblib.dump(label_encoder, f"model/encoder_{target_column}.joblib")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# ...

# %% [markdown]
# ## Modeling

# %%
cleaned_df = df[['Status', 'Fathers_qualification', 'Mothers_qualification', 'Fathers_occupation', 'Mothers_occupation','Scholarship_holder', 'Tuition_fees_up_to_date']]
cleaned_df.head()
# Out:
#      Status  Fathers_qualification  Mothers_qualification  Fathers_occupation  \
# 0   Dropout                     12                     19                   9
# 1  Graduate                      3                      1                   3
# 2   Dropout                     37                     37                   9
# 3  Graduate                     37                     38                   3
# 4  Graduate                     38                     37                   9
#
#    Mothers_occupation  Scholarship_holder  Tuition_fees_up_to_date
# 0                   5                   0                        1
# 1                   3                   0                        0
# 2                   9                   0                        0
# 3                   5                   0                        1
# 4                   9                   0                        1

# %% [markdown]
# ## Evaluation
